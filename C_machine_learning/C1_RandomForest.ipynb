# %% [markdown]
# # C1 — Random Forest (Cross-Section)
#
# **Famiglia C — Machine Learning** | Approccio non parametrico
#
# ## Modello
# - Input: dataset collassato come in A1
# - Importanza variabili via permutation importance
# - Benchmark non-lineare
# - `class_weight='balanced'` per dataset sbilanciato (85.9% silenti)
#
# > **TODO**: da implementare
