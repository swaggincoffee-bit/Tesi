# %% [markdown]
# # C2 — Gradient Boosting (XGBoost / LightGBM)
#
# **Famiglia C — Machine Learning** | Approccio non parametrico
#
# ## Modello
# - Opzionale: confronto più forte di C1
# - Migliore performance ma minore interpretabilità
#
# > **TODO**: da implementare (opzionale)
