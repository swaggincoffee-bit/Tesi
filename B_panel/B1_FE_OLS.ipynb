# %% [markdown]
# # B1 — Effetti Fissi Lineari (OLS Within)
#
# **Famiglia B — Panel** | Una riga per contatore × finestra
#
# ## Modello
# ```
# silente_it = αᵢ + β·X_it_dinamiche + ε_it
# ```
# - Elimina via demeaning tutto ciò che non varia within
# - Stima solo variabili dinamiche
# - Controllo robusto per eterogeneità non osservata
#
# > **TODO**: da implementare
