# %% [markdown]
# # B4 — Mixed Logit (Effetti Casuali)
#
# **Famiglia B — Panel** | Una riga per contatore × finestra
#
# ## Modello
# ```
# P(silente_it=1) = ∫ σ(Xβ + αᵢ) f(αᵢ) dαᵢ
# ```
# - Integrazione numerica
# - Mantiene tutti i contatori
#
# > **TODO**: da implementare
