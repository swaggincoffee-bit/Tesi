# %% [markdown]
# # B2 — Effetti Casuali Lineari (GLS)
#
# **Famiglia B — Panel** | Una riga per contatore × finestra
#
# ## Modello
# ```
# silente_it = β₀ + β·X_it + αᵢ + ε_it
# ```
# - Stima sia variabili statiche che dinamiche
# - Richiede Cov(αᵢ, X) = 0
# - Test di Hausman per scelta tra B1 e B2
#
# > **TODO**: da implementare
