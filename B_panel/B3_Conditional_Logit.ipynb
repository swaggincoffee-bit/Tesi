# %% [markdown]
# # B3 — Conditional Logit (Effetti Fissi)
#
# **Famiglia B — Panel** | Una riga per contatore × finestra
#
# ## Modello
# ```
# P(silente_it=1 | Σ silente_i)  condizionato sulla somma
# ```
# - Elimina αᵢ tramite condizionamento
# - Esclude contatori senza variazione (sempre 0 o sempre 1)
#
# > **TODO**: da implementare
